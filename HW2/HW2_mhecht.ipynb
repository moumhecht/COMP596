# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Problem 1: Analyze the following equations graphically. In each case, sketch the vector field on the real line, find all the fixed points and classify their stability.
# ### A.  $$\frac{dx}{dt}  = 2x^2-9$$

# %%
n = 20

# inintialize
x = np.linspace(-3,3,n)
z = np.zeros(n)
zeros = np.zeros(n)
# fill array 
for ii in range(0,n):
    z[ii] = 2. * (x[ii])**2. - 9.

# plot
plt.plot(x,z)
plt.plot(x,zeros)

# %%
x,t = np.meshgrid(np.linspace(-4,4,10),np.linspace(-10,10,10))
dx = 2.* x**2 - 9. 
dt = np.ones(np.size(t))
plt.quiver(x,t,dx,dt)

# %% [markdown]
# We can verify this mathematically, noting that the fixed points will be where $\frac{dx}{dt}=0$:
# $$\frac{dx}{dt} = 2x^2 - 9 = 0 \implies \frac{9}{2}= x^2 \implies  x = \pm \sqrt{\frac{9}{2}} = \pm 2.121$$

# %% [markdown]
# Then the fixed point $x = -2.121$ goes from increasing to decreasing (from left to right) and is a stable fixed point.
#
# The fixed point $x = 2.121$ goes from decreasing to increasing and is thus an unstable fixed point.

# %% [markdown]
# ### B. $$\frac{dx}{dt} = 1-2\cos(x)$$

# %%
n = 100

# inintialize
x = np.linspace(-10,10,n)
z = np.zeros(n)
zeros = np.zeros(n)
# fill array 
for ii in range(0,n):
    z[ii] = 1. - 2.* np.cos(x[ii])

# plot
plt.plot(x,z)
plt.plot(x,zeros)

# %%
x,t = np.meshgrid(np.linspace(-6,8,10),np.linspace(-5,5,10))
dx =1.- 2.* np.cos(x)
dt = np.ones(np.size(t))
plt.quiver(x,t,dx,dt)

# %% [markdown]
# Setting $\frac{dx}{dt} = 0$, we get
# $$\frac{dx}{dt} =1-2\cos(x) = 0 \implies \cos(x) = \frac{1}{2} \implies x = \cos^{-1}\left(\frac{1}{2}\right) $$
# So $x = \frac{\pi}{3} +2\pi m$ or $x = \frac{5\pi}{3} + 2\pi m$ for some integer $m$.

# %% [markdown]
# For fixed points given by  $x = \frac{\pi}{3} +2\pi m$:

# %%
np.pi/3.
# Out:
# 1.0471975511965976

# %%
np.pi/3 +2*np.pi
# Out:
# 7.330382858376184

# %%
np.pi/3 -2*np.pi
# Out:
# -5.235987755982989

# %% [markdown]
# The fixed points go from decreasing to increasing and are unstable fixed points.

# %% [markdown]
# For fixed points given by $x = \frac{5\pi}{3} + 2\pi m$:

# %%
5.* np.pi /3.
# Out:
# 5.235987755982989

# %%
5.* np.pi/3. - 2. * np.pi
# Out:
# -1.0471975511965974

# %% [markdown]
# The fixed points go from increasing to decreasing and are stable fixed points.

# %% [markdown]
# ## Problem 2: Analyze the growth model graphically. Sketch the vector field on the real line, find all the fixed points and classify their stability.
# ### $$\frac{dN}{dt}= r N \left(1-\frac{N}{K}\right)\left(\frac{N}{K^-}-1\right)$$

# %% [markdown]
# ### Show your plot in terms of literal parameters, assume $K^- <K$

# %% [markdown]
# The fixed points are determined by $\frac{dN}{dt} = 0$, then we find that the fixed points are $N = 0$, $N = K^-$, and $N = K$

# %% [markdown]
# We will first consider the case for positive $r$:

# %% [markdown]
# When $ 0<N <K^-$, $\frac{dN}{dt}<0 $.
#
# When $K^- < N< K$, $\frac{dN}{dt}>0$
